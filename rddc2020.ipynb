# %% [markdown]
# <a href="https://colab.research.google.com/github/556-wangbiao/search_picture_original/blob/master/rddc2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/USC-InfoLab/rddc2020.git
# Out:
# Cloning into 'rddc2020'...
# remote: Enumerating objects: 519, done.
# remote: Counting objects: 100% (514/514), done.
# remote: Compressing objects: 100% (338/338), done.
# remote: Total 519 (delta 197), reused 450 (delta 161), pack-reused 5
# Receiving objects: 100% (519/519), 5.47 MiB | 12.47 MiB/s, done.
# Resolving deltas: 100% (197/197), done.

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd /content/rddc2020
# Out:
# /content/rddc2020

# %%
# !pip install -r requirements.txt

# %%
# !bash yolov5/scripts/dataset_setup_for_yolov5.sh
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# mv test1/India/images/India_008046.jpg test1/test_images
# mv test1/India/images/India_009361.jpg test1/test_images
# mv test1/India/images/India_002086.jpg test1/test_images
# mv test1/India/images/India_002928.jpg test1/test_images
# mv test1/India/images/India_003924.jpg test1/test_images
# mv test1/India/images/India_001468.jpg test1/test_images
# mv test1/India/images/India_000172.jpg test1/test_images
# mv test1/India/images/India_008917.jpg test1/test_images
# mv test1/India/images/India_002929.jpg test1/test_images
# mv test1/India/images/India_008884.jpg test1/test_images
# mv test1/India/images/India_008721.jpg test1/test_images
# mv test1/India/images/India_008454.jpg test1/test_images
# mv test1/India/images/India_000211.jpg test1/test_images
# mv test1/India/images/India_009637.jpg test1/test_images
# mv test1/India/images/India_002779.jpg test1/test_images
# mv test1/India/images/India_002814.jpg test1/test_images
# ...

# %%
# !bash yolov5/scripts/download_IMSC_grddc2020_weights.sh
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/gdown", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/gdown/cli.py", line 151, in main
#     filename = download(
#   File "/usr/local/lib/python3.10/dist-packages/gdown/download.py", line 219, in download
#     for file in os.listdir(osp.dirname(output) or "."):
# FileNotFoundError: [Errno 2] No such file or directory: 'weights/IMSC'
# Traceback (most recent call last):
#   File "/usr/local/bin/gdown", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/gdown/cli.py", line 151, in main
#     filename = download(
#   File "/usr/local/lib/python3.10/dist-packages/gdown/download.py", line 219, in download
#     for file in os.listdir(osp.dirname(output) or "."):
# FileNotFoundError: [Errno 2] No such file or directory: 'weights/IMSC'
# Traceback (most recent call last):
#   File "/usr/local/bin/gdown", line 8, in <module>
# ...

# %%
# !bash /content/rddc2020/yolov5/scripts/download_IMSC_grddc2020_weights.sh
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/gdown", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/gdown/cli.py", line 151, in main
#     filename = download(
#   File "/usr/local/lib/python3.10/dist-packages/gdown/download.py", line 219, in download
#     for file in os.listdir(osp.dirname(output) or "."):
# FileNotFoundError: [Errno 2] No such file or directory: 'weights/IMSC'
# Traceback (most recent call last):
#   File "/usr/local/bin/gdown", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/gdown/cli.py", line 151, in main
#     filename = download(
#   File "/usr/local/lib/python3.10/dist-packages/gdown/download.py", line 219, in download
#     for file in os.listdir(osp.dirname(output) or "."):
# FileNotFoundError: [Errno 2] No such file or directory: 'weights/IMSC'
# Traceback (most recent call last):
#   File "/usr/local/bin/gdown", line 8, in <module>
# ...

# %%
# %pwd
# Out:
# '/content/rddc2020'

# %%
# %cd yolov5/
# Out:
# /content/rddc2020/yolov5

# %%
# !bash scripts/download_IMSC_grddc2020_weights.sh
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1F_0MHIBuO1wgVwePk6UAuFudKmCf_7Fs
# To: /content/rddc2020/yolov5/weights/IMSC/last_95_448_32_aug2.pt
# 100% 177M/177M [00:05<00:00, 32.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Fw6_ku3Z8aTdy4vwjZatHTkaNyeT7ZoZ
# To: /content/rddc2020/yolov5/weights/IMSC/last_95_640_16.pt
# 100% 178M/178M [00:02<00:00, 62.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Xu2KDBkD09E7ItOkKrodM_XzOQu-6Mhl
# To: /content/rddc2020/yolov5/weights/IMSC/last_95.pt
# 100% 178M/178M [00:01<00:00, 127MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1ky9aZ1ygiy2qXlY_zcpj_4QI1ccfQTcE
# To: /content/rddc2020/yolov5/weights/IMSC/last_100_100_640_16.pt
# 100% 178M/178M [00:03<00:00, 48.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Wd1KA8j-q6qRQzy6ytLEav89xsmiqLFB
# To: /content/rddc2020/yolov5/weights/IMSC/last_120_640_32_aug2.pt
# 100% 178M/178M [00:04<00:00, 42.5MB/s]

# %%
# !bash weights/download_weights.sh
# Out:
# ...
# 100% 14.5M/14.5M [00:00<00:00, 52.7MB/s]
#
# ...
# 100% 41.9M/41.9M [00:01<00:00, 28.2MB/s]
#
# ...
# 100% 91.6M/91.6M [00:02<00:00, 34.7MB/s]
#
# ...
# 100% 170M/170M [00:09<00:00, 17.9MB/s]

# %%
# !rm -r  /content/rddc2020/yolov5/runs

# %%
# !python train.py --data data/road.yaml --cfg models/yolov5x.yaml --weights weights/yolov5x.pt --batch-size 64
# Out:
# 2023-07-11 06:28:28.180797: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-11 06:28:30.359092: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Using CPU
#
# Namespace(weights='weights/yolov5x.pt', cfg='models/yolov5x.yaml', data='data/road.yaml', hyp='data/hyp.scratch.yaml', epochs=300, batch_size=64, img_size=[640, 640], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, name='', device='', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, logdir='runs/', workers=8, total_batch_size=64, world_size=1, global_rank=-1)
# ...
